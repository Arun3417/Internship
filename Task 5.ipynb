# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data is Extracted from Website using instant Web Scacper.After that Data Cleaning is done in Microsoft Excel.

# %%
#Importing Data

# %%
data= pd.read_csv(r"C:\Users\Arun\Data.csv", encoding= 'latin1')

# %%
data
# Out:
#                 STATE Women (15 Years & Above) Men (15 Years & Above)
# 0   Andaman & Nicobar                   31.30%                 58.70%
# 1                  AP                    3.80%                 22.60%
# 2           Arunachal                   18.80%                 50.30%
# 3               Assam                   22.10%                 51.80%
# 4               Bihar                    5.00%                 48.80%
# 5          Chandigarh                    0.60%                 12.10%
# 6        Chattishgarh                   17.30%                 43.10%
# 7                 D&N                    2.90%                 38.60%
# 8               Delhi                    2.20%                 26.30%
# 9                 Goa                    2.60%                 18.20%
# 10            Gujarat                    8.70%                 41.10%
# 11            Haryana                    2.50%                 29.10%
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 3 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   STATE                     36 non-null     object
#  1   Women (15 Years & Above)  36 non-null     object
#  2   Men (15 Years & Above)    36 non-null     object
# dtypes: object(3)
# memory usage: 992.0+ bytes
