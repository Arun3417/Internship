# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv(r"C:\Users\Arun\Downloads\IDSSeries.csv", encoding='latin1')

# %%
df1.head()
# Out:
#     ï»¿"Series Code"                                              Topic  \
# 0     BM.GSR.TOTL.CD  Economic Policy & Debt: Balance of payments: C...
# 1     BN.CAB.XOKA.CD  Economic Policy & Debt: Balance of payments: C...
# 2  BX.GRT.EXTA.CD.DT  Economic Policy & Debt: Balance of payments: R...
# 3  BX.GRT.TECH.CD.DT  Economic Policy & Debt: Balance of payments: R...
# 4     BX.GSR.TOTL.CD  Economic Policy & Debt: Balance of payments: C...
#
#                                       Indicator Name  \
# 0  Imports of goods, services and primary income ...
# 1              Current account balance (current US$)
# 2  Grants, excluding technical cooperation (curre...
# 3         Technical cooperation grants (current US$)
# 4  Exports of goods, services and primary income ...
#
#                                     Short definition  \
# 0  Imports of goods, services and primary income ...
# 1  Current account balance shows the difference b...
# ...

# %%
df2=pd.read_csv(r"C:\Users\Arun\Downloads\IDSCountry.csv")

# %%
df2
# Out:
#     Country Code    Short Name    Table Name                     Long Name  \
# 0            AFG   Afghanistan   Afghanistan  Islamic State of Afghanistan
# 1            AGO        Angola        Angola   People's Republic of Angola
# 2            ALB       Albania       Albania           Republic of Albania
# 3            ARG     Argentina     Argentina            Argentine Republic
# 4            ARM       Armenia       Armenia           Republic of Armenia
# ..           ...           ...           ...                           ...
# 131          XKX        Kosovo        Kosovo            Republic of Kosovo
# 132          YEM         Yemen   Yemen, Rep.             Republic of Yemen
# 133          ZAF  South Africa  South Africa      Republic of South Africa
# 134          ZMB        Zambia        Zambia            Republic of Zambia
# 135          ZWE      Zimbabwe      Zimbabwe          Republic of Zimbabwe
#
#     2-alpha code       Currency Unit  \
# ...

# %%
df3= pd.read_csv(r"C:\Users\Arun\Downloads\IDSCountry-Series.csv")

# %%
df3
# Out:
#     CountryCode         SeriesCode  \
# 0           AFG  BX.KLT.DINV.CD.DT
# 1           AFG     DT.DOD.DECT.CD
# 2           AGO  BX.KLT.DINV.CD.DT
# 3           AGO     DT.DOD.DECT.CD
# 4           ALB  BX.KLT.DINV.CD.DT
# ..          ...                ...
# 262         ZAF     DT.DOD.DECT.CD
# 263         ZMB  BX.KLT.DINV.CD.DT
# 264         ZMB     DT.DOD.DECT.CD
# 265         ZWE  BX.KLT.DINV.CD.DT
# 266         ZWE     DT.DOD.DECT.CD
#
#                                            DESCRIPTION  Unnamed: 3
# 0    Data on Foreign Direct Investment are based on...         NaN
# 1    Long-term public and publicly guaranteed debt ...         NaN
# 2    Data on Foreign Direct Investment are based on...         NaN
# 3    Long-term public and publicly guaranteed debt ...         NaN
# 4    Data on Foreign Direct Investment are based on...         NaN
# ..                                                 ...         ...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ï»¿"Series Code"                     214 non-null    object
#  1   Topic                                214 non-null    object
#  2   Indicator Name                       214 non-null    object
#  3   Short definition                     214 non-null    object
#  4   Long definition                      214 non-null    object
#  5   Unit of measure                      0 non-null      float64
#  6   Periodicity                          214 non-null    object
#  7   Base Period                          0 non-null      float64
#  8   Other notes                          0 non-null      float64
#  9   Aggregation method                   214 non-null    object
#  10  Limitations and exceptions           0 non-null      float64
# ...
